# %%
# !git clone https://github.com/Livolofsson/ECG-project.git
# Out:
# Cloning into 'ECG-project'...
# ...

# %%
import os

# helper function
def exists(path):
    val = os.path.exists(path)
    if val:
        print(f'{path} already exits. Using cached. Delete it manually to recieve it again!')
    return val

# clone requirements.txt if not yet available
if not exists('requirements.txt'):
    # !git clone https://gist.github.com/dgedon/8a7b91714568dc35d0527233e9ceada4.git req
    # !mv req/requirements.txt .
    # !yes | rm -r req
# Out:
# Cloning into 'req'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3 (from 1)
# Receiving objects: 100% (3/3), done.

# %%
git config --global user.email "astrid_liv@hotmail.com"
git config --global user.name "LivOlofsson"
# Out:
#   File "/tmp/ipython-input-1970197886.py", line 1
#     git config --global user.email "astrid_liv@hotmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/af_classification.ipynb" .
# !git add af_classification.ipynb
# !git commit -m "testing git in colab"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@9506b6e88e0a.(none)')
